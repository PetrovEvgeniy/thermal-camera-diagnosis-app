# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from sklearn.ensemble import IsolationForest
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from PIL import Image

# %% [markdown]
# # Load images from the train and test directories

# %%
train_directory = "./train/*.png"
test_directory = "./test/*.png"

train_image_paths = glob.glob(train_directory)
test_image_paths = glob.glob(test_directory)

print(f"Number of training images: {len(train_image_paths)}")
print(f"Number of testing images: {len(test_image_paths)}")
# Out:
# Number of training images: 85
# Number of testing images: 57

# %% [markdown]
# # Function to load and flatten images

# %%
def load_images(image_paths):
    image_data = []
    
    for path in image_paths:
        image = Image.open(path).convert('L')
        image = image.resize((80, 60))
        image_array = np.array(image).flatten()
        image_data.append(image_array)
    return np.array(image_data)

# %% [markdown]
# # Load the images

# %%
train_image_data = load_images(train_image_paths)
test_image_data = load_images(test_image_paths)

print(f"Train image data shape: {train_image_data.shape}")
print(f"Test image data shape: {test_image_data.shape}")
# Out:
# Train image data shape: (85, 4800)
# Test image data shape: (57, 4800)

# %% [markdown]
# # Normalize the data

# %%
scaler = StandardScaler()
train_image_data_scaled = scaler.fit_transform(train_image_data)
test_image_data_scaled = scaler.transform(test_image_data)

# %% [markdown]
# # Implement Isolation Forest

# %%
isolation_forest = IsolationForest(contamination=0.1)
isolation_forest.fit(train_image_data_scaled)
# Out:
# IsolationForest(contamination=0.1)

# %% [markdown]
# # Predict anomalies in the test set and measure inference times

# %%
import time
import numpy as np

# Initialize an empty list to store inference times
inference_times = []

# Perform predictions and measure time for each
for i, path in enumerate(test_image_paths):
    start_time = time.time()  # Start time before prediction
    anomaly_scores = isolation_forest.predict([test_image_data_scaled[i]])  # Predict single image data
    end_time = time.time()  # End time after prediction
    
    # Calculate the inference time in milliseconds
    inference_time = (end_time - start_time)
    inference_times.append(inference_time)

    # Store the prediction result
    anomaly_prediction = "Anomaly" if anomaly_scores == -1 else "Normal"
    print(f"Test Image: {path.split('/')[-1]} - Prediction: {anomaly_prediction}")

# Calculate mean inference time
mean_inference_time = np.mean(inference_times) * 1000

print(f"Mean Inference Time: {mean_inference_time:.2f} ms")
# Out:
# Test Image: test\20240826_150708cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150711cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150714cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150717cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150723cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150726cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150744cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150747cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150753cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150756cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150759cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150811cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150820cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150829cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150838cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150844cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150856cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150859cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150902cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150906cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150908cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150914cam1_thermal.png - Prediction: Normal
# Test Image: test\20240826_150917cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150919cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150935cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150941cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150946cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150947cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150948cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150955cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150956cam1_thermal.png - Prediction: Anomaly
# Test Image: test\20240826_150957cam1_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014611_e_kettle_thermal.png - Prediction: Normal
# Test Image: test\a_20241009_014616_e_kettle_thermal.png - Prediction: Normal
# Test Image: test\a_20241009_014621_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014626_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014631_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014638_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014641_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014646_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014651_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014656_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014701_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014706_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014711_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014716_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014721_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014726_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014731_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014736_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014741_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014746_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014751_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014756_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014801_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014806_e_kettle_thermal.png - Prediction: Anomaly
# Test Image: test\a_20241009_014811_e_kettle_thermal.png - Prediction: Anomaly
# Mean Inference Time: 18.64 ms

# %% [markdown]
# # Count anomalies

# %%
num_anomalies = np.sum(anomaly_predictions == "Anomaly")
num_normal = np.sum(anomaly_predictions == "Normal")

print(f"Total anomalies detected in test set: {num_anomalies}")
print(f"Total normal cases detected in test set: {num_normal}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22504\387533574.py in <module>
# ----> 1 num_anomalies = np.sum(anomaly_predictions == "Anomaly")
#       2 num_normal = np.sum(anomaly_predictions == "Normal")
#       3
#       4 print(f"Total anomalies detected in test set: {num_anomalies}")
#       5 print(f"Total normal cases detected in test set: {num_normal}")
#
# NameError: name 'anomaly_predictions' is not defined

# %% [markdown]
# # Calculate Evaluation Metrics

# %%
from sklearn.metrics import roc_auc_score, precision_score, recall_score, roc_curve
import os
import matplotlib.pyplot as plt

# Create a new array of 0s and 1s for labels
y_test = [1 if os.path.basename(path).startswith("a_") else -1 for path in test_image_paths]

# Calculate AUC-ROC (negate scores because lower scores indicate anomalies)
auc_roc = roc_auc_score(y_test, -anomaly_scores)  # Use -anomaly_scores to reflect anomaly likelihood
print(f"AUC-ROC: {auc_roc:.3f}")

# Binarize anomaly_scores based on a threshold (assuming 0 as the threshold for binary classification)
threshold = 0
y_pred = [1 if score < threshold else -1 for score in anomaly_scores]  # Negative scores -> anomalies (label = 1)

# Calculate Precision and Recall
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")

# Plot ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, -anomaly_scores)
plt.plot(fpr, tpr, marker='.', color='r')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve (AUC-ROC: {auc_roc:.2f})')
plt.grid(True)
plt.show()
# Out:
# AUC-ROC: 0.663
# Precision: 0.548
# Recall: 0.920

# %% [markdown]
# # Visualize one anomaly and one normal image

# %%
anomaly_indices = np.where(anomaly_predictions == "Anomaly")[0]
normal_indices = np.where(anomaly_predictions == "Normal")[0]

# Show an example anomaly image
if len(anomaly_indices) > 0:
    anomaly_image = Image.open(test_image_paths[anomaly_indices[10]])
    plt.imshow(anomaly_image, cmap='gray')
    plt.title('Example Anomaly Image')
    plt.show()

# Show an example normal image
if len(normal_indices) > 0:
    normal_image = Image.open(test_image_paths[normal_indices[1]])
    plt.imshow(normal_image, cmap='gray')
    plt.title('Example Normal Image')
    plt.show()
